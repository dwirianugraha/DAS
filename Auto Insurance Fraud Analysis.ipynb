# %% [markdown]
# <br>
#
# <span style="font-size:2em;font-weight:bold">Auto Insurance Fraud Analysis</span>
#
# In this exercise, we'll be creating a simple [Flask application](https://algoritma-autoinsurance.herokuapp.com/) using [fraud-detection-insurance data](https://www.kaggle.com/sanjeevkallepalli/fraud-detection-insurance) for autoinsurance fraud detection. Full data glossary can be accessed [here](https://github.com/t3981-h/AI-Fraud/blob/master/README.md).
#
# This notebook contains guidances & tasks on the data processing for the application.

# %% [markdown]
# <span style="font-size:1.5em;font-weight:bold">Libraries & Setup</span>:

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# # Load & Pre-process data
#
# Let's begin by reading our dataset in. The data will be using is `autoinsurance.csv` which located under `data/` directory:

# %%
insurance = pd.read_csv('data/autoinsurance.csv')
insurance.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# A very common step on your exploratory process is to make sure that all your columns have stored in the right data types. In the following cell, use `dtypes` to acquire information of data type of each column:

# %%
## Your code here
insurance.dtypes
# Out:
# months_as_customer                int64
# age                               int64
# policy_number                     int64
# policy_bind_date               category
# policy_state                   category
# policy_csl                     category
# policy_deductable                 int64
# policy_annual_premium           float64
# umbrella_limit                    int64
# insured_zip                       int64
# insured_sex                    category
# insured_education_level        category
# insured_occupation             category
# insured_hobbies                category
# insured_relationship           category
# capital-gains                     int64
# capital-loss                      int64
# incident_date                  category
# incident_type                  category
# collision_type                 category
# incident_severity              category
# authorities_contacted          category
# incident_state                 category
# incident_city                  category
# incident_location              category
# incident_hour_of_the_day          int64
# number_of_vehicles_involved       int64
# property_damage                category
# bodily_injuries                   int64
# witnesses                         int64
# police_report_available        category
# total_claim_amount                int64
# injury_claim                      int64
# property_claim                    int64
# vehicle_claim                     int64
# auto_make                      category
# auto_model                     category
# auto_year                         int64
# fraud_reported                 category
# _c39                            float64
# dtype: object

# %% [markdown]
# Notice that all categorical informations from the data were stored as `object` rather than `category`.
#
# ## Adjust Data Types
#
# **Task 1**: Fill in the blank (`___`) part of the code below to cast all `object` to `category`:

# %%
catcol = insurance.select_dtypes('object').columns
insurance[catcol] = insurance[catcol].apply(lambda x: x.astype('category'))

# %% [markdown]
# ## Wrap as Function
#
# Lastly, let's wrap the whole process above as a function named `load_data()`. This process is essential because in your Flask application later, you will need to define all your data processing as specific functions.
#
# **Task 3**: Fill in the blank (`___`) part with the same process you have done previously to complete the function.

# %%
def load_data():
    # Read data
    insurance = pd.read_csv('data/autoinsurance.csv')
    
    # Adjust dtypes
    catcol = insurance.select_dtypes('object').columns
    insurance[catcol] = insurance[catcol].apply(lambda x: x.astype('category'))
    
    return(insurance)

# %% [markdown]
# Congratulations, you have done the very first challenge of this capstone project!
#
# If you take a look at the project directory, you will find two separate scripts; `app.py` and `helper.py`. `app.py` handles the routing and within `helper.py` you would define function to be called in `app`.
#
# If you open up the `helper.py`, you will find all the functions needed to create the dashboard contents such as plots and data values. You may now copy the `load_data()` function definition above and overwrite the existing function on the script and save it.
#
# In `app.py`, notice that there's a line of `data = load_data()`. that you've save your function in separate python file/script, you can import the function to another script as the following:

# %%
data = load_data()
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# <span style="font-size:2em;font-weight:bold">Data Wrangling & Visualization</span>
#
# Now that you're data is ready, we're now ready to prepare the explanatory data in our dashboard!
#
# Within `app.py` you will see the `index()` function will return a rendered templates along with some variables:
# - `card_data`: quick summary including **Fraud Rate**, **Average Claim Amount** & **Fraud Loss**
# - `plot_age`: **Fraud Reported by Age group** plot in **by Profile** tab
# - `plot_premium`: **Months as Customer per Policy Annual Premium** plot in **by Profile** tab
# - `plot_incident`: **Number of Fraud Reported per Day** plot in **by Report** tab
# - `plot_report`: **Police Report Availability** plot in **by Report** tab
#
# The values and plots above were resulted from all EDA techniques you have learned in the pervious workshops. Your next challenge is to recall how to use pandas subsetting method, aggregation tables and simple visualization!

# %% [markdown]
# # Extract Quick Summary
#
# Let's acquire the needed information for the quick summary in `card_data`. There are 3 values you need to extract:
# - **Fraud Rate**: The percentage of fraud reported (`Fraud_reported` = Y)
# - **Average Claim Amount**: The Average of total claim amount at this quarter (`total_claim_amount`)
# - **Total Fraud Loss**: Total of fraud loss at this quarter (`total_claim_amount`)
#
# **Task 4**: Fill in the blank (`___`) part of the code below to create a proportion table of fraud and not fraud customer!

# %%
pd.crosstab(index=data['fraud_reported'],columns='count',normalize=True)*100
# Out:
# col_0           count
# fraud_reported
# N                75.3
# Y                24.7

# %% [markdown]
# We can extract the value from our table by using `.loc[]` subsetting method.
#
# **Task 5**: Fill in the blank (`___`) part to extract the information of fraud reported!

# %%
percent_fraud = float((pd.crosstab(index=data['fraud_reported'],columns='count',normalize=True)).loc['Y', 'count']*100)

f'{percent_fraud}%'
# Out:
# '24.7%'

# %% [markdown]
# **Task 6**: Extract total fraud loss with similar method! Total fraud loss is total claim amount at reported fraud costumer

# %%
fraud_loss = pd.crosstab(index=data['fraud_reported']
               ,columns='jumlah'
               ,values= data['total_claim_amount']
               , aggfunc='sum').loc['Y', 'jumlah']

f'US$ {fraud_loss:,}'
# Out:
# 'US$ 14,894,620'

# %% [markdown]
# **Task 7**: The average total claim amount stored the average (`mean`) value of `total_claim_amount` variable. Extract the value on the cell code below!

# %%
## Your code here

data['total_claim_amount'].median()
# Out:
# 58055.0

# %% [markdown]
# <span style="font-size:1.5em;font-weight:bold">Update the application scripts!</span>

# %% [markdown]
# Lastly, follow these instructions to complete the next part of your application scripts:
#
# - **On app.py:**
#     - "Uncomment" the codes under `# generate value for cards` section then use the code in **Task 4** , **Task 5** & **Task 6** to complete the blank (`___`) part of the line

# %% [markdown]
# # Generate Plot
#
# ## by Profile
#
# The "by Profile" tab contains explanatory analysis on the proportion of reported fraud by the policy holder profile. There are two plots you need to recreate for this tab; **Months as Customer per Policy Annual Premium** and **Fraud Reported by Age group**

# %% [markdown]
# ### Fraud Reported by Age group
#
# The Fraud Reported by Age group plot compares age group to see the frequencies of the fraud reported at each age group.

# %% [markdown]
# #### Categorize age group
#
# The `tenure_months` column indicates the total amount of months that the customer has been with the company by the end of the quarter. Your next task is to create a new column named `tenure_group` which categorize the tenure months by the following conditions:
# - **19 - 24**: customer with age 19 years old up until 24 years old
# - **24 - 30**: customer with age 24 years old up until 30 years old
# - **and so on**
#
# **Task 2**: Fill in the blank (`___`) part to create the `age_group` column!

# %%
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
# Tenure Months to grouping categories
def age_grouping(data):
    if(data.age <= 24):
        return '19 - 24'
    elif(data.age > 24 and data.age <= 30) : 
        return '25 - 30'
    elif(data.age > 30 and data.age <= 35) : 
        return '31 - 35'
    elif(data.age > 35 and data.age <= 40) : 
        return '36 - 40'
    elif(data.age > 40 and data.age <= 45) : 
        return '41 - 45'
    elif(data.age > 45 and data.age <= 50) : 
        return '46 - 50'
    elif(data.age > 50 and data.age <= 55) : 
        return '51 - 55'
    elif(data.age > 55 and data.age <= 59) : 
        return '56 - 59'
    else : 
        return '60+'

data['age_group'] = data.apply(age_grouping,axis = 1)

# %%
# Adjust category order
age_group_order = ['19 - 24', '25 - 30', '31 - 35', '36 - 40', '41 - 45', '46 - 50', '51 - 55', '56 - 59', '60+']
pd.Categorical(data['age_group'], categories = age_group_order, ordered=True)
# Out:
# ['46 - 50', '41 - 45', '25 - 30', '41 - 45', '41 - 45', ..., '36 - 40', '41 - 45', '31 - 35', '60+', '60+']
# Length: 1000
# Categories (9, object): ['19 - 24' < '25 - 30' < '31 - 35' < '36 - 40' ... '46 - 50' < '51 - 55' < '56 - 59' < '60+']

# %%
# Adjust category order
age_group_order = ['19 - 24', '25 - 30', '31 - 35', '36 - 40', '41 - 45', '46 - 50', '51 - 55', '56 - 59', '60+']
data['age_group'] = pd.Categorical(data['age_group'], categories = age_group_order, ordered=True)

# %%
data.groupby('age_group').count()
# Out:
#            months_as_customer  age  policy_number  policy_bind_date  \
# age_group
# 19 - 24                    26   26             26                26
# 25 - 30                   171  171            171               171
# 31 - 35                   195  195            195               195
# 36 - 40                   201  201            201               201
# 41 - 45                   184  184            184               184
# 46 - 50                   109  109            109               109
# 51 - 55                    50   50             50                50
# 56 - 59                    37   37             37                37
# 60+                        27   27             27                27
#
#            policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# age_group
# 19 - 24              26          26                 26                     26
# 25 - 30             171         171                171                    171
# 31 - 35             195         195                195                    195
# 36 - 40             201         201                201                    201
# 41 - 45             184         184                184                    184
# 46 - 50             109         109                109                    109
# 51 - 55              50          50                 50                     50
# 56 - 59              37          37                 37                     37
# 60+                  27          27                 27                     27
#
#            umbrella_limit  insured_zip  ...  police_report_available  \
# age_group                               ...
# 19 - 24                26           26  ...                       26
# 25 - 30               171          171  ...                      171
# 31 - 35               195          195  ...                      195
# 36 - 40               201          201  ...                      201
# 41 - 45               184          184  ...                      184
# 46 - 50               109          109  ...                      109
# 51 - 55                50           50  ...                       50
# 56 - 59                37           37  ...                       37
# 60+                    27           27  ...                       27
#
#            total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# age_group
# 19 - 24                    26            26              26             26
# 25 - 30                   171           171             171            171
# 31 - 35                   195           195             195            195
# 36 - 40                   201           201             201            201
# 41 - 45                   184           184             184            184
# 46 - 50                   109           109             109            109
# 51 - 55                    50            50              50             50
# 56 - 59                    37            37              37             37
# 60+                        27            27              27             27
#
#            auto_make  auto_model  auto_year  fraud_reported  _c39
# age_group
# 19 - 24           26          26         26              26     0
# 25 - 30          171         171        171             171     0
# 31 - 35          195         195        195             195     0
# 36 - 40          201         201        201             201     0
# 41 - 45          184         184        184             184     0
# 46 - 50          109         109        109             109     0
# 51 - 55           50          50         50              50     0
# 56 - 59           37          37         37              37     0
# 60+               27          27         27              27     0
#
# [9 rows x 40 columns]

# %% [markdown]
# **Task 8**:
# Use `pd.crosstab()` to get the frequency proportion, then recall how to use `.plot(kind = 'barh')` to create a horizontal bar plot. Before you using crosstab to get the only fraud reported data, you need to subset the data first and save it at `fraud_data`.

# %%
## Your code here
fraud_data = data[data['fraud_reported'] == 'Y']

age_profile = pd.crosstab(index=fraud_data['age_group'],columns='count')

age_profile
# Out:
# col_0      count
# age_group
# 19 - 24        8
# 25 - 30       38
# 31 - 35       55
# 36 - 40       39
# 41 - 45       49
# 46 - 50       23
# 51 - 55       14
# 56 - 59       12
# 60+            9

# %% [markdown]
# You can also enhance the visualization such as adjusting the color by add the color parameter to your plot function call `.plot(kind = 'bar',color=['#c34454'])`.
#
# For now, **do not mind the plot's customization** as you can copy-and-paste the codes defined under the `plot_age()` function in `helper.py`.

# %%
# Plot configuration
ax = age_profile.plot.barh(title = "Fraud Reported by Age group", legend= False, color = '#c34454')

# %%
# Plot configuration
ax = age_profile.plot.barh(title = "Fraud Reported by Age group", legend= False, color = '#c34454')

ax.xaxis.set_major_formatter(mtick.PercentFormatter())
plt.legend(['Retain', 'Churn'],fancybox=True,shadow=True)
plt.axes().get_yaxis().set_label_text('')
plt.title('Phone Service Customer')
# Out:
# Text(0.5, 1.0, 'Phone Service Customer')

# %% [markdown]
# ### Months as Customer per Policy Annual Premium

# %% [markdown]
# We need a helper function to make the plot more beautiful. You can just run and then skip this cell.

# %%
def tocolor(data):
    if(data.fraud_reported == 'Y'):
        return '#53a4b1'
    else : 
        return '#c34454'
    
data.fcolor = data.apply(tocolor,axis=1)

# %% [markdown]
# **Task 9**:
# Using the same steps as what you did on "Months as Customer per Policy Annual Premium" plot, except this time the plot is a scatter plot that compare how long the policy holder as customer with how much their annual premium to see how those two variable relation with each other, and how is the characteristic of the fraud reported profile based on those 2 numeric variable.
#
# For now, **do not mind the plot's customization** as you can copy-and-paste the codes defined under the `plot_premium()` function in `helper.py`.

# %%
## Your code here

ax = data.plot.scatter(x= 'months_as_customer', 
                       y = 'policy_annual_premium', 
                       c=data.fcolor,title = "Months as Customer per Policy Annual Premium",
                       figsize=(8, 6))

lab_y = mpatches.Patch(color='#53a4b1', label='Y')
lab_n = mpatches.Patch(color='#c34454', label='N')
plt.legend(handles = [lab_y ,lab_n], bbox_to_anchor=(1.17, 1))
plt.xlabel("Months as Customer")
plt.ylabel("Policy Annual Premium")
# Out:
# Text(0, 0.5, 'Policy Annual Premium')

# %%
## Your code here

ax = data.plot.scatter(x= ________, 
                       y = __________, 
                       c=data.fcolor,title = "Months as Customer per Policy Annual Premium",
                       figsize=(8, 6))

lab_y = mpatches.Patch(color='#53a4b1', label='Y')
lab_n = mpatches.Patch(color='#c34454', label='N')
plt.legend(handles = [lab_y ,lab_n], bbox_to_anchor=(1.17, 1))
plt.xlabel("Months as Customer")
plt.ylabel("Policy Annual Premium")
# Out:
# Text(0, 0.5, 'Policy Annual Premium')

# %% [markdown]
# ## by Report
#
# The "by Report" tab contains explanatory analysis on how is the relationship between incident report with the fraud cases. There are two plots you need to recreate for this tab; **Number of Report per Day** and **Police Report Availability**
#
# ### Number of Report per Day
#
# **Task 10**:
# The Number of Report per Day plot visualize on how much the fraud cases happened at each day at this 1st quarter.
#
# You can start by create the frequency table for the visualization. First we need a helper function to make it easier to wrangling the data. then you can create your frequency table, this time with `pivot_table()`

# %%
def tonum(data):
    if(data.fraud_reported == 'Y'):
        return 1
    else : 
        return 0
    
data['fnum'] = data.apply(tonum,axis=1)

# %%
data.dtypes
# Out:
# months_as_customer                int64
# age                               int64
# policy_number                     int64
# policy_bind_date               category
# policy_state                   category
# policy_csl                     category
# policy_deductable                 int64
# policy_annual_premium           float64
# umbrella_limit                    int64
# insured_zip                       int64
# insured_sex                    category
# insured_education_level        category
# insured_occupation             category
# insured_hobbies                category
# insured_relationship           category
# capital-gains                     int64
# capital-loss                      int64
# incident_date                  category
# incident_type                  category
# collision_type                 category
# incident_severity              category
# authorities_contacted          category
# incident_state                 category
# incident_city                  category
# incident_location              category
# incident_hour_of_the_day          int64
# number_of_vehicles_involved       int64
# property_damage                category
# bodily_injuries                   int64
# witnesses                         int64
# police_report_available        category
# total_claim_amount                int64
# injury_claim                      int64
# property_claim                    int64
# vehicle_claim                     int64
# auto_make                      category
# auto_model                     category
# auto_year                         int64
# fraud_reported                 category
# _c39                            float64
# age_group                      category
# fnum                              int64
# dtype: object

# %%
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... injury_claim property_claim vehicle_claim   auto_make  \
# 0         466132  ...         6510          13020         52080        Saab
# 1         468176  ...          780            780          3510    Mercedes
# 2         430632  ...         7700           3850         23100       Dodge
# 3         608117  ...         6340           6340         50720   Chevrolet
# 4         610706  ...         1300            650          4550      Accura
# ..           ...  ...          ...            ...           ...         ...
# 995       431289  ...        17440           8720         61040       Honda
# 996       608177  ...        18080          18080         72320  Volkswagen
# 997       442797  ...         7500           7500         52500      Suburu
# 998       441714  ...         5220           5220         36540        Audi
# 999       612260  ...          460            920          3680    Mercedes
#
#     auto_model  auto_year  fraud_reported _c39 age_group fnum
# 0          92x       2004               Y  NaN   46 - 50    1
# 1         E400       2007               Y  NaN   41 - 45    1
# 2          RAM       2007               N  NaN   25 - 30    0
# 3        Tahoe       2014               Y  NaN   41 - 45    1
# 4          RSX       2009               N  NaN   41 - 45    0
# ..         ...        ...             ...  ...       ...  ...
# 995     Accord       2006               N  NaN   36 - 40    0
# 996     Passat       2015               N  NaN   41 - 45    0
# 997    Impreza       1996               N  NaN   31 - 35    0
# 998         A5       1998               N  NaN       60+    0
# 999       E400       2007               N  NaN       60+    0
#
# [1000 rows x 42 columns]

# %%
data.pivot_table(
    index='incident_date',
    values='fnum',
    aggfunc='count')
# Out:
#                fnum
# incident_date
# 2015-01-01       19
# 2015-01-02       11
# 2015-01-03       18
# 2015-01-04       12
# 2015-01-05        7
# 2015-01-06       17
# 2015-01-07       25
# 2015-01-08       22
# 2015-01-09       17
# 2015-01-10       24
# 2015-01-11        9
# 2015-01-12       19
# 2015-01-13       21
# 2015-01-14       19
# 2015-01-15       15
# 2015-01-16       16
# 2015-01-17       15
# 2015-01-18       18
# 2015-01-19       23
# 2015-01-20       18
# 2015-01-21       19
# 2015-01-22       14
# 2015-01-23       13
# 2015-01-24       24
# 2015-01-25       10
# 2015-01-26       11
# 2015-01-27       13
# 2015-01-28       15
# 2015-01-29       11
# 2015-01-30       21
# 2015-01-31       20
# 2015-02-01       18
# 2015-02-02       28
# 2015-02-03       13
# 2015-02-04       24
# 2015-02-05       16
# 2015-02-06       20
# 2015-02-07       10
# 2015-02-08       17
# 2015-02-09       13
# 2015-02-10       10
# 2015-02-11       10
# 2015-02-12       20
# 2015-02-13       16
# 2015-02-14       18
# 2015-02-15       16
# 2015-02-16       16
# 2015-02-17       26
# 2015-02-18       15
# 2015-02-19       10
# 2015-02-20       14
# 2015-02-21       19
# 2015-02-22       20
# 2015-02-23       19
# 2015-02-24       17
# 2015-02-25       18
# 2015-02-26       17
# 2015-02-27       14
# 2015-02-28       18
# 2015-03-01       12

# %%
## Your code here

def tonum(data):
    if(data.fraud_reported == 'Y'):
        return 1
    else : 
        return 0
    
data['fnum'] = data.apply(tonum,axis=1)

# %%
timeseries = data.pivot_table(
    index='incident_date',
    values='fnum',
    aggfunc='count')

# %%
ax = timeseries.plot(legend=False, title = "Number of Fraud per Day",color='#c34454', figsize=(8, 6))

# Plot Configuration
plt.xlabel('incident_date')
# Out:
# Text(0.5, 0, 'incident_date')

# %% [markdown]
# Again, **do not mind the plot's customization** as you can copy-and-paste the codes defined under the `plot_incident()` function in `helper.py`.

# %% [markdown]
# ### Police Report Availability

# %% [markdown]
# **Task 11**:
# The last plot you need to recreate is the Police Report Availability. This plot visualize how the relationship of Police Report Availability with the fraud report.
#
# Since we'll separate the bars by the `fraud_report`, we will need to wrangling the data a bit to make the table we want for the visualisation.

# %%
df_fraud = data[data.fraud_reported == 'Y'].pivot_table(index='police_report_available',values='fraud_reported',aggfunc='count')

df_nfraud = data[data.fraud_reported == 'N'].pivot_table(index='police_report_available',values='fraud_reported',aggfunc='count')

p_report = pd.concat([df_fraud,df_nfraud],axis=1)
p_report
# Out:
#                          fraud_reported  fraud_reported
# police_report_available
# ?                                    89             254
# NO                                   86             257
# YES                                  72             242

# %% [markdown]
# Once your data is ready, recall how to use `.plot(kind = 'bar')` to create a bar plot. You can add the `stacked` Parameter to stack of the barplot.
#
# Once again, **do not mind the plot's customization** as you can copy-and-paste the codes defined under the `plot_report()` function in `helper.py`.

# %%
pd.concat([df_fraud,df_nfraud],axis=1).plot.bar(stacked = 'police_report_available',color =['#c34454','#53a4b1'],title = "Police Report Availability", figsize=(8, 6))
# Out:
# <AxesSubplot:title={'center':'Police Report Availability'}, xlabel='police_report_available'>

# %%
ax = pd.concat([df_fraud,df_nfraud],axis=1).plot.bar(stacked = 'police_report_available',color =['#c34454','#53a4b1'],title = "Police Report Availability", figsize=(8, 6))

# Plot Configuration
plt.legend(['fraud','not fraud'], bbox_to_anchor=(1, 1))
plt.xlabel("police report available'")
# Out:
# Text(0.5, 0, "police report available'")

# %% [markdown]
# <span style="font-size:1.5em;font-weight:bold">Update the application scripts!</span>
#
# Now that your plots are ready, it's time to move them to the dashboard!
#
# - **On helper.py**:
#     - Use the code on **Task 8-11** to complete the functions below:
#         - Task 8 --> `plot_age()`
#         - Task 9 --> `plot_premium()`
#         - Task 10 --> `plot_incident()`
#         - Task 11 --> `plot_report()`
#
# - **On app.py:**
#     - Now that all the functions are completed, you can call all functions from helper.py using the asterisk (\*) symbol: `from helper import *`
#     - "Uncomment" the codes under `# generate plot` section to generate the plots
#     - Lastly, in `render_template()` at the end of `index()` in `app.py`, uncomment the remaining codes.

# %% [markdown]
# # Create-Your-Own Analysis
#
# We have prepared a Create-Your-Own tab on the apps where you can play around with the data frame and come up with your own analysis perspective. Don't forget to do the following steps:
#
# - Pass a variable onto the `render_template()` from `index()`
# - Create a separate function on `helper.py` for data wrangling and preprocessing, either returning a dataframe, simple value, or a plot to keep the `app.py` as clean as possible and easy to debug at later times
# - Edit the `index.html` to make sure it display your intended output on the page. You can copy-and-paste the skeleton from the other plots or values

# %%
data.dtypes
# Out:
# months_as_customer                int64
# age                               int64
# policy_number                     int64
# policy_bind_date               category
# policy_state                   category
# policy_csl                     category
# policy_deductable                 int64
# policy_annual_premium           float64
# umbrella_limit                    int64
# insured_zip                       int64
# insured_sex                    category
# insured_education_level        category
# insured_occupation             category
# insured_hobbies                category
# insured_relationship           category
# capital-gains                     int64
# capital-loss                      int64
# incident_date                  category
# incident_type                  category
# collision_type                 category
# incident_severity              category
# authorities_contacted          category
# incident_state                 category
# incident_city                  category
# incident_location              category
# incident_hour_of_the_day          int64
# number_of_vehicles_involved       int64
# property_damage                category
# bodily_injuries                   int64
# witnesses                         int64
# police_report_available        category
# total_claim_amount                int64
# injury_claim                      int64
# property_claim                    int64
# vehicle_claim                     int64
# auto_make                      category
# auto_model                     category
# auto_year                         int64
# fraud_reported                 category
# _c39                            float64
# dtype: object

# %%
data[data['fraud_reported']=='Y'].select_dtypes(include=['category'])
# Out:
#     policy_bind_date policy_state policy_csl insured_sex  \
# 0         2014-10-17           OH    250/500        MALE
# 1         2006-06-27           IN    250/500        MALE
# 3         1990-05-25           IL    250/500      FEMALE
# 5         2006-10-12           OH    250/500      FEMALE
# 14        1998-12-28           OH    250/500      FEMALE
# ..               ...          ...        ...         ...
# 974       1990-05-16           IN    100/300      FEMALE
# 977       2003-03-06           IN    100/300        MALE
# 982       2007-02-09           IN   500/1000        MALE
# 986       2013-04-30           IN    100/300        MALE
# 987       2013-05-01           IL   500/1000        MALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        MD       craft-repair        sleeping
# 1                        MD  machine-op-inspct         reading
# 3                       PhD       armed-forces     board-games
# 5                       PhD       tech-support  bungie-jumping
# 14                  College  machine-op-inspct     board-games
# ..                      ...                ...             ...
# 974                      JD   transport-moving     video-games
# 977               Associate       adm-clerical     board-games
# 982             High School    exec-managerial       cross-fit
# 986                 College  handlers-cleaners        kayaking
# 987                      JD       craft-repair        yachting
#
#     insured_relationship incident_date             incident_type  ...  \
# 0                husband    2015-01-25  Single Vehicle Collision  ...
# 1         other-relative    2015-01-21             Vehicle Theft  ...
# 3              unmarried    2015-01-10  Single Vehicle Collision  ...
# 5              unmarried    2015-01-02   Multi-vehicle Collision  ...
# 14         not-in-family    2015-01-15  Single Vehicle Collision  ...
# ..                   ...           ...                       ...  ...
# 974                 wife    2015-02-08   Multi-vehicle Collision  ...
# 977       other-relative    2015-02-21   Multi-vehicle Collision  ...
# 982       other-relative    2015-01-01   Multi-vehicle Collision  ...
# 986        not-in-family    2015-02-19  Single Vehicle Collision  ...
# 987       other-relative    2015-01-13  Single Vehicle Collision  ...
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 3        Major Damage                Police             OH     Arlington
# 5        Major Damage                  Fire             SC     Arlington
# 14         Total Loss                Police             SC   Springfield
# ..                ...                   ...            ...           ...
# 974      Major Damage                Police             SC     Riverwood
# 977      Major Damage             Ambulance             WV   Springfield
# 982      Minor Damage                Police             NY     Arlington
# 986      Minor Damage                 Other             WV     Riverwood
# 987      Major Damage                 Other             NC     Hillsdale
#
#       incident_location property_damage police_report_available  auto_make  \
# 0        9935 4th Drive             YES                     YES       Saab
# 1          6608 MLK Hwy               ?                       ?   Mercedes
# 3      6956 Maple Drive               ?                      NO  Chevrolet
# 5    8973 Washington St              NO                      NO       Saab
# 14       6851 3rd Drive              NO                     YES      Dodge
# ..                  ...             ...                     ...        ...
# 974      3884 Pine Lane              NO                       ?  Chevrolet
# 977    4937 Flute Drive               ?                      NO     Suburu
# 982        7511 1st Ave               ?                     YES        BMW
# 986        8269 Sky Hwy             YES                       ?     Toyota
# 987       5663 Oak Lane               ?                       ?  Chevrolet
#
#      auto_model fraud_reported
# 0           92x              Y
# 1          E400              Y
# 3         Tahoe              Y
# 5            95              Y
# 14         Neon              Y
# ..          ...            ...
# 974       Tahoe              Y
# 977     Impreza              Y
# 982          M5              Y
# 986  Highlander              Y
# 987       Tahoe              Y
#
# [247 rows x 21 columns]

# %%
data[data['fraud_reported']=='Y'].select_dtypes(include=['category']).groupby('insured_sex').count()
# Out:
#              policy_bind_date  policy_state  policy_csl  \
# insured_sex
# FEMALE                    126           126         126
# MALE                      121           121         121
#
#              insured_education_level  insured_occupation  insured_hobbies  \
# insured_sex
# FEMALE                           126                 126              126
# MALE                             121                 121              121
#
#              insured_relationship  incident_date  incident_type  \
# insured_sex
# FEMALE                        126            126            126
# MALE                          121            121            121
#
#              collision_type  incident_severity  authorities_contacted  \
# insured_sex
# FEMALE                  126                126                    126
# MALE                    121                121                    121
#
#              incident_state  incident_city  incident_location  \
# insured_sex
# FEMALE                  126            126                126
# MALE                    121            121                121
#
#              property_damage  police_report_available  auto_make  auto_model  \
# insured_sex
# FEMALE                   126                      126        126         126
# MALE                     121                      121        121         121
#
#              fraud_reported
# insured_sex
# FEMALE                  126
# MALE                    121

# %%
data[data['fraud_reported']=='Y'].groupby('incident_severity').count()
# Out:
#                    months_as_customer  age  policy_number  policy_bind_date  \
# incident_severity
# Major Damage                      167  167            167               167
# Minor Damage                       38   38             38                38
# Total Loss                         36   36             36                36
# Trivial Damage                      6    6              6                 6
#
#                    policy_state  policy_csl  policy_deductable  \
# incident_severity
# Major Damage                167         167                167
# Minor Damage                 38          38                 38
# Total Loss                   36          36                 36
# Trivial Damage                6           6                  6
#
#                    policy_annual_premium  umbrella_limit  insured_zip  ...  \
# incident_severity                                                      ...
# Major Damage                         167             167          167  ...
# Minor Damage                          38              38           38  ...
# Total Loss                            36              36           36  ...
# Trivial Damage                         6               6            6  ...
#
#                    police_report_available  total_claim_amount  injury_claim  \
# incident_severity
# Major Damage                           167                 167           167
# Minor Damage                            38                  38            38
# Total Loss                              36                  36            36
# Trivial Damage                           6                   6             6
#
#                    property_claim  vehicle_claim  auto_make  auto_model  \
# incident_severity
# Major Damage                  167            167        167         167
# Minor Damage                   38             38         38          38
# Total Loss                     36             36         36          36
# Trivial Damage                  6              6          6           6
#
#                    auto_year  fraud_reported  _c39
# incident_severity
# Major Damage             167             167     0
# Minor Damage              38              38     0
# Total Loss                36              36     0
# Trivial Damage             6               6     0
#
# [4 rows x 39 columns]

# %%
sv_fraud = data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')

sv_nfraud = data[data.fraud_reported == 'N'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')

p_report = pd.concat([sv_fraud,sv_nfraud],axis=1)
p_report
# Out:
#                    fraud_reported  fraud_reported
# incident_severity
# Major Damage                  167             109
# Minor Damage                   38             316
# Total Loss                     36             244
# Trivial Damage                  6              84

# %%
ax = pd.concat([sv_fraud,sv_nfraud],axis=1).plot.barh(stacked = 'incident_severity',color =['#ee0000','#00dd00'],title = "Incident Report Severity", figsize=(8, 6))

# Plot Configuration
plt.legend(['fraud','not fraud'], bbox_to_anchor=(1, 1))
plt.xlabel("police report available'")
# Out:
# Text(0.5, 0, "police report available'")

# %%
Claim_Fraud = data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')

Claim_All = data.pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')

Kontribusi_Fraud = Claim_Fraud/Claim_All*100

Kontribusi_Fraud
# Out:
#                    fraud_reported
# incident_severity
# Major Damage            60.507246
# Minor Damage            10.734463
# Total Loss              12.857143
# Trivial Damage           6.666667

# %%
round(Kontribusi_Fraud.loc['Major Damage', 'fraud_reported'],2)
# Out:
# 60.51

# %%
Claim_Fraud = data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')
Claim_All = data.pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count')
Kontribusi_Fraud = round((Claim_Fraud/Claim_All*100).loc['Major Damage', 'fraud_reported'],2)
Kontribusi_Fraud
# Out:
# 60.51

# %%
p_report = pd.concat([Claim_Fraud,Claim_All,Kontribusi_Fraud],axis=1)
p_report
# Out:
#                    fraud_reported  fraud_reported  fraud_reported
# incident_severity
# Major Damage                  167             276       60.507246
# Minor Damage                   38             354       10.734463
# Total Loss                     36             280       12.857143
# Trivial Damage                  6              90        6.666667

# %%
pd.crosstab(index=(data[data.fraud_reported == 'Y'])['incident_severity'],columns='count',normalize=True)

# %%
 

percent_Severity_Major_fraud = round(float((pd.crosstab(index=(data[data.fraud_reported == 'Y'])['incident_severity'],columns='count',normalize=True)).loc['Major Damage', 'count']*100),2)

f'{percent_Severity_Major_fraud}%'
# Out:
# '67.61%'

# %%
data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count').sort_values('fraud_reported', ascending=True).head(1).iloc[0:1 , 0:1]
# Out:
#                    fraud_reported
# incident_severity
# Trivial Damage                  6

# %%
data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count').sort_values('fraud_reported', ascending=False).reset_index().iloc[0 , 0]
# Out:
# 'Major Damage'

# %%
data[data.fraud_reported == 'Y'].pivot_table(index='incident_severity',values='fraud_reported',aggfunc='count').sort_values('fraud_reported', ascending=True).reset_index().iloc[0 , 0]
# Out:
# 'Trivial Damage'

# %%
data[data['fraud_reported']=='Y'].select_dtypes(include='category')
# Out:
#     policy_bind_date policy_state policy_csl insured_sex  \
# 0         2014-10-17           OH    250/500        MALE
# 1         2006-06-27           IN    250/500        MALE
# 3         1990-05-25           IL    250/500      FEMALE
# 5         2006-10-12           OH    250/500      FEMALE
# 14        1998-12-28           OH    250/500      FEMALE
# ..               ...          ...        ...         ...
# 974       1990-05-16           IN    100/300      FEMALE
# 977       2003-03-06           IN    100/300        MALE
# 982       2007-02-09           IN   500/1000        MALE
# 986       2013-04-30           IN    100/300        MALE
# 987       2013-05-01           IL   500/1000        MALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        MD       craft-repair        sleeping
# 1                        MD  machine-op-inspct         reading
# 3                       PhD       armed-forces     board-games
# 5                       PhD       tech-support  bungie-jumping
# 14                  College  machine-op-inspct     board-games
# ..                      ...                ...             ...
# 974                      JD   transport-moving     video-games
# 977               Associate       adm-clerical     board-games
# 982             High School    exec-managerial       cross-fit
# 986                 College  handlers-cleaners        kayaking
# 987                      JD       craft-repair        yachting
#
#     insured_relationship incident_date             incident_type  ...  \
# 0                husband    2015-01-25  Single Vehicle Collision  ...
# 1         other-relative    2015-01-21             Vehicle Theft  ...
# 3              unmarried    2015-01-10  Single Vehicle Collision  ...
# 5              unmarried    2015-01-02   Multi-vehicle Collision  ...
# 14         not-in-family    2015-01-15  Single Vehicle Collision  ...
# ..                   ...           ...                       ...  ...
# 974                 wife    2015-02-08   Multi-vehicle Collision  ...
# 977       other-relative    2015-02-21   Multi-vehicle Collision  ...
# 982       other-relative    2015-01-01   Multi-vehicle Collision  ...
# 986        not-in-family    2015-02-19  Single Vehicle Collision  ...
# 987       other-relative    2015-01-13  Single Vehicle Collision  ...
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 3        Major Damage                Police             OH     Arlington
# 5        Major Damage                  Fire             SC     Arlington
# 14         Total Loss                Police             SC   Springfield
# ..                ...                   ...            ...           ...
# 974      Major Damage                Police             SC     Riverwood
# 977      Major Damage             Ambulance             WV   Springfield
# 982      Minor Damage                Police             NY     Arlington
# 986      Minor Damage                 Other             WV     Riverwood
# 987      Major Damage                 Other             NC     Hillsdale
#
#       incident_location property_damage police_report_available  auto_make  \
# 0        9935 4th Drive             YES                     YES       Saab
# 1          6608 MLK Hwy               ?                       ?   Mercedes
# 3      6956 Maple Drive               ?                      NO  Chevrolet
# 5    8973 Washington St              NO                      NO       Saab
# 14       6851 3rd Drive              NO                     YES      Dodge
# ..                  ...             ...                     ...        ...
# 974      3884 Pine Lane              NO                       ?  Chevrolet
# 977    4937 Flute Drive               ?                      NO     Suburu
# 982        7511 1st Ave               ?                     YES        BMW
# 986        8269 Sky Hwy             YES                       ?     Toyota
# 987       5663 Oak Lane               ?                       ?  Chevrolet
#
#      auto_model fraud_reported
# 0           92x              Y
# 1          E400              Y
# 3         Tahoe              Y
# 5            95              Y
# 14         Neon              Y
# ..          ...            ...
# 974       Tahoe              Y
# 977     Impreza              Y
# 982          M5              Y
# 986  Highlander              Y
# 987       Tahoe              Y
#
# [247 rows x 21 columns]

# %%
pd.crosstab(index=data['fraud_reported']
               ,columns='jumlah'
               ,values= data['total_claim_amount']
               , aggfunc='sum').loc['Y', 'jumlah']
# Out:
# 14894620

# %%
## Your code here
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
data[data['fraud_reported']=='Y'].select_dtypes(include='category')
# Out:
#     policy_bind_date policy_state policy_csl insured_sex  \
# 0         2014-10-17           OH    250/500        MALE
# 1         2006-06-27           IN    250/500        MALE
# 3         1990-05-25           IL    250/500      FEMALE
# 5         2006-10-12           OH    250/500      FEMALE
# 14        1998-12-28           OH    250/500      FEMALE
# ..               ...          ...        ...         ...
# 974       1990-05-16           IN    100/300      FEMALE
# 977       2003-03-06           IN    100/300        MALE
# 982       2007-02-09           IN   500/1000        MALE
# 986       2013-04-30           IN    100/300        MALE
# 987       2013-05-01           IL   500/1000        MALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        MD       craft-repair        sleeping
# 1                        MD  machine-op-inspct         reading
# 3                       PhD       armed-forces     board-games
# 5                       PhD       tech-support  bungie-jumping
# 14                  College  machine-op-inspct     board-games
# ..                      ...                ...             ...
# 974                      JD   transport-moving     video-games
# 977               Associate       adm-clerical     board-games
# 982             High School    exec-managerial       cross-fit
# 986                 College  handlers-cleaners        kayaking
# 987                      JD       craft-repair        yachting
#
#     insured_relationship incident_date             incident_type  ...  \
# 0                husband    2015-01-25  Single Vehicle Collision  ...
# 1         other-relative    2015-01-21             Vehicle Theft  ...
# 3              unmarried    2015-01-10  Single Vehicle Collision  ...
# 5              unmarried    2015-01-02   Multi-vehicle Collision  ...
# 14         not-in-family    2015-01-15  Single Vehicle Collision  ...
# ..                   ...           ...                       ...  ...
# 974                 wife    2015-02-08   Multi-vehicle Collision  ...
# 977       other-relative    2015-02-21   Multi-vehicle Collision  ...
# 982       other-relative    2015-01-01   Multi-vehicle Collision  ...
# 986        not-in-family    2015-02-19  Single Vehicle Collision  ...
# 987       other-relative    2015-01-13  Single Vehicle Collision  ...
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 3        Major Damage                Police             OH     Arlington
# 5        Major Damage                  Fire             SC     Arlington
# 14         Total Loss                Police             SC   Springfield
# ..                ...                   ...            ...           ...
# 974      Major Damage                Police             SC     Riverwood
# 977      Major Damage             Ambulance             WV   Springfield
# 982      Minor Damage                Police             NY     Arlington
# 986      Minor Damage                 Other             WV     Riverwood
# 987      Major Damage                 Other             NC     Hillsdale
#
#       incident_location property_damage police_report_available  auto_make  \
# 0        9935 4th Drive             YES                     YES       Saab
# 1          6608 MLK Hwy               ?                       ?   Mercedes
# 3      6956 Maple Drive               ?                      NO  Chevrolet
# 5    8973 Washington St              NO                      NO       Saab
# 14       6851 3rd Drive              NO                     YES      Dodge
# ..                  ...             ...                     ...        ...
# 974      3884 Pine Lane              NO                       ?  Chevrolet
# 977    4937 Flute Drive               ?                      NO     Suburu
# 982        7511 1st Ave               ?                     YES        BMW
# 986        8269 Sky Hwy             YES                       ?     Toyota
# 987       5663 Oak Lane               ?                       ?  Chevrolet
#
#      auto_model fraud_reported
# 0           92x              Y
# 1          E400              Y
# 3         Tahoe              Y
# 5            95              Y
# 14         Neon              Y
# ..          ...            ...
# 974       Tahoe              Y
# 977     Impreza              Y
# 982          M5              Y
# 986  Highlander              Y
# 987       Tahoe              Y
#
# [247 rows x 21 columns]

# %%
Fraud= data[data['fraud_reported']=='Y'].select_dtypes(include='category')

# %%
Fraud.dtypes
# Out:
# policy_bind_date           category
# policy_state               category
# policy_csl                 category
# insured_sex                category
# insured_education_level    category
# insured_occupation         category
# insured_hobbies            category
# insured_relationship       category
# incident_date              category
# incident_type              category
# collision_type             category
# incident_severity          category
# authorities_contacted      category
# incident_state             category
# incident_city              category
# incident_location          category
# property_damage            category
# police_report_available    category
# auto_make                  category
# auto_model                 category
# fraud_reported             category
# dtype: object

# %%
Fraud_IncidentType = data[data.fraud_reported == 'Y'].pivot_table(index='incident_type',values='fraud_reported',aggfunc='count')
NFraud_IncidentType = data[data.fraud_reported == 'N'].pivot_table(index='incident_type',values='fraud_reported',aggfunc='count')

p_report = pd.concat([Fraud_IncidentType,NFraud_IncidentType],axis=1)
p_report
# Out:
#                           fraud_reported  fraud_reported
# incident_type
# Multi-vehicle Collision              114             305
# Parked Car                             8              76
# Single Vehicle Collision             117             286
# Vehicle Theft                          8              86

# %%
ax = pd.concat([Fraud_IncidentType,NFraud_IncidentType],axis=1).plot.bar(stacked = 'incident_severity',color =['#ee0000','#00dd00'],title = "Incident Report Severity", figsize=(8, 6))

# %%
Fraud_Education = data[data.fraud_reported == 'Y'].pivot_table(
        index='insured_education_level', values='fraud_reported', aggfunc='count')

# %%
Fraud_Education = data[data.fraud_reported == 'Y'].pivot_table(
        index='insured_education_level', values='fraud_reported', aggfunc='count')

ax = Fraud_Education.plot.barh(title="Fraud Reported by Age group",
                               legend=False,
                               color='#c34454',
                               figsize=(8, 6))

# %%
Fraud_Education = data[data.fraud_reported == 'Y'].pivot_table(index='insured_education_level', values='fraud_reported', aggfunc='count')
NFraud_Education = data[data.fraud_reported == 'N'].pivot_table(index='insured_education_level', values='fraud_reported', aggfunc='count')
    
ax = pd.concat(
        [
            Fraud_Education,
            NFraud_Education],
        axis=1).plot.bar(
            stacked='insured_education_level',
            color=[
                '#ee0000',
                '#00dd00'],
        title="Incident Report Severity",
        figsize=(
                8,
                6))

# %%
Fraud_IncidentType = data[data.fraud_reported == 'Y'].pivot_table(
        index='property_damage', values='fraud_reported', aggfunc='count')
NFraud_IncidentType = data[data.fraud_reported == 'N'].pivot_table(
        index='property_damage', values='fraud_reported', aggfunc='count')
ax = pd.concat(
        [
            Fraud_IncidentType,
            NFraud_IncidentType],
        axis=1).plot.bar(
            stacked='incident_severity',
            color=[
                '#ff3300',
                '#ffbb22'],
        title="Laporan Klaiment Fraud Berdasarkan dari Kerusakan",
        figsize=(
                8,
                10))

# %%
round(float((pd.crosstab(index=(data[data.fraud_reported == 'Y'])['property_damage'],columns='count',normalize=True)).loc['?', 'count']*100),2)
# Out:
# 41.7
